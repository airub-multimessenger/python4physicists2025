# %% [markdown]
# # Homework 5

# %% [markdown]
# ## Name:

# %% [markdown]
# In this exercise, we will build a small cozy garden game using multiple Python classes. You will create a player who can water plants to gain XP (XP = Experience points) and harvest ripe crops to restore energy.
#
#
# **(A)** (1P)
#
# Create the ````Plant```` class that represents a plant in your garden game with the following attributes:
#
# - **name**: The name of your plant
# - **times_watered**: This counts how many times the plant has been watered (start at 0)
# - **xp_per_water**: How much XP a player earns for watering this plant (default: 5)
#
# After writing the new class, create a new instance of it. Name the plant "Rose"and set the ````xp_per_water```` to 10 instead of the default.

# %%
# Your solution

# %% [markdown]
# **(B)** (1 P)
#
# Create the ````HarvestablePlant```` class, which inherits from the ````Plant```` class. This class represents a plant that can be harvested to restore the player's energy.
#
# Use **inheritance** to reuse the ````Plant```` class ````HarvestablePlant(Plant)````.
#
# Include the following additional attributes for the new class:
#
# - **energy_gain**: The amount of energy a player gains when harvesting this plant (default: 20)
# - **harvested**: A boolean indicating whether the plant has already been harvested (start as False).
#
# Test your code by creating a new instance of it. The new harvestable plant has the name "pumpkin".

# %%
# Your solution

# %% [markdown]
# **(C)** (3 P)
#
# Now you can create the ````Player```` class which represents the player in your garden game. The player gains XP but loses energy when watering the plants and gains energy when harvesting plants (because he can eat the harvest).
#
# Include the following attributes:
#
#
# - **name**: The name of your player
# - **xp**: The player's experience points (start at 0).
# - **energy**: The player's energy level (start at 100).
#
#
# and the following methods:
#
#
# - **water(self, plant)**:
#   -  This method waters a ````Plant```` instance,
#   -  Increases the plant’s times_watered by 1,
#   -  Increases the player’s XP using the plant’s ````xp_per_water````and the player's ````xp```` attribute,
#   -  Decreases the player’s energy by 5.
#   -  Prints the action, how many energy it costs and how many XP are gained.
#
#
#
#
# - **harvest(self, plant)**:
#   - Harvests a ````HarvestablePlant```` instance if it hasn’t been harvested yet and if it was watered more than 3 times. If not, do not harvest and print out how many times it was watered.
#   - Sets harvested to **True**.
#   - Increases the player’s energy by the plant’s ````energy_gain````.
#   - Prints the action, how many energy points it costs and how many XP are gained.
#
#
# Try out your new class by creating a player with a name, then water the rose. Afterwards, harvest the pumpkin one time and see what happens. Water it again until you can harvest it.

# %%
# Your solution

# %% [markdown]
# The problem ends here but feel free to expand your game with more classes and methods or introducing more plants or even multiple players!
