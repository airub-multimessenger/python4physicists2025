# %% [markdown]
# # Homework 8

# %% [markdown]
# # Name:

# %% [markdown]
# ### Attention: You will create files for this homework but you only need to submit the Jupyter notebook.

# %% [markdown]
# **Note:** Do not forget to import the necessary modules for each question.

# %% [markdown]
# **(A)** (1P)
#
# Write code to
#
# 1. Create a folder named ```planets_data``` in the notebook directory using pathlib.
# 2. Store each dictionary in the ```planets_info``` in a separate JSON file named after the planet (e.g Magrathea.json).

# %%
planets_info = [
    {"name": "Magrathea", "distance": 57.9, "diameter": 4879, "has_rings": False},
    {"name": "Betelgeuse_V", "distance": 108.2, "diameter": 12104, "has_rings": False},
    {"name": "Vogsphere", "distance": 149.6, "diameter": 12742, "has_rings": False},
    {"name": "Beeper", "distance": 227.9, "diameter": 6779, "has_rings": False},
    {"name": "Milliways", "distance": 778.5, "diameter": 139820, "has_rings": True},
]

# %%
## SOLUTION

# %% [markdown]
# **(B)** (1P)
#
# 1. Using the glob module, load all the JSON files into ```planet_files```.
# 2. Add elements into the lists ```planet_names```, ```planet_distances``` and ```planet_diameters``` such that they respectively contain the names, distances and diameters of all the planets.
#
# **Note:** Do not use the ```planets_data``` list. You should only use the data you load into ```planet_files```.

# %%
planet_names = []
planet_distances = []
planet_diameters = []

# %%
## SOLUTION

# %% [markdown]
# **(C)** (1P) Using NumPy array operations,
#
# 1. Print the mean distance and the standard deviation in distance.
# 2. Find and print the name of the planet with the largest diameter.
#
# **Note:** Convert lists into NumPy arrays first.

# %%
## SOLUTION

# %% [markdown]
# **(D)** (2P) Using NumPy operations,
#
# 1. Create a linearly spaced array named ```orbital_points``` with 10 points starting from the closest planet to the furthest planet.
# 2. Find and print the distances between two consecutive points in this list.
# 3. Print the array excluding the first and last element.

# %%
## SOLUTION
