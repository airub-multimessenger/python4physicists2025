# %% [markdown]
# # Homework 3

# %% [markdown]
# ## Name:

# %% [markdown]
# # Problem 1: **(2 P)**
#
# You are given a person’s birthday as a list:

# %%
birthday = [12,6,2000]

# %% [markdown]
# Write a program that loops through all possible combinations of days, months, and years in the following ranges:
#
# Day: 0–30
#
# Month: 3–8
#
# Year: 1995–2004
#
# For each combination, create a list in the form ````[day, month, year]```` and store it in a list called combi.
#
# Keep track of how many combinations have been checked.
# As soon as the combination matches the given birthday, stop the search and print after how many attempts the correct date was found.

# %%
# Your solution

# %% [markdown]
# # Problem 2: **(1 P)**
#
# Imagine a game where the goal is to guess the correct color code. Each time a guess is submitted, the player receives feedback indicating whether a correct color is included in the guess and whether it is in the correct position.
# The code below should compare the two lists ````color_code```` and ````guess_list```` and if the guess contains the correct color and if it is also the correct position. But there are some bugs inside this code. Can you find them and fix the code?
#
# The code below is intended to compare the two lists, ````color_code```` and ````guess_list```` and to check for each color in the guess whether it is in the code and in the correct position. However, the code contains some bugs that prevent it from working correctly.
#
# Your task is to copy the content of the cell and paste it into a separate cell below so you keep the original version unchanged. **Identify and fix the bugs in the code.**
#
# Add comments at the lines you modify, briefly explaining what you changed.

# %%
color_code = ['Red', 'Orange', 'Blue', 'Green']

# %%
guess_1 = ['Green', 'Yellow', 'Blue', 'Green']
guess_2 = ['Green', 'Red', 'Blue', 'Green']
guess_3 = ['Red', 'Orange', 'Blue', 'Green']

guess_list = [guess_1, guess_2, guess_3]

# %%
# The code you have to fix:

n = 0
for i in guess_list:
    print(f"Guess {i}")
    
    for c in range((i)):
        if i[c] == color_code[c]:
            print("\t Correct color, correct position")
            n += 1
        elif: i[c] in colour_code:
            print("\t Correct color, but wrong position)
        if n == 4:
        print("\t Looks like you've unlocked the mystery!")

# %%
# Your solution:

# %% [markdown]
# # Problem 3: **(2 P)**

# %% [markdown]
# A local pub is organizing a quiz night! They received applications from several groups who want to participate. Each group provided the number of people in their team. The pub can only accept 4 groups, and each must have at least 4 members.

# %%
applications = {
    "The Smart Alecs": 3,
    "Quiztopher Nolan": 5,
    "Beer Pressure": 6,
    "Les Quizerables": 5,
    "The Quizard of Oz": 4,
    "Let's Get Quizzical": 2,
    "Risky Quizness": 7,
    "Tequila Mockingbird": 5
}

# %% [markdown]
# **(A)** **(1 P)** Write a program that:
# - Uses a `while` loop to go through the `applications` dictionary and select groups that have at least 4 members.
# - Stops once 4 valid groups have been accepted.
# - Stores the accepted groups in a new dictionary called `accepted_groups`.
#
# Hint: You can use `list(applications.items())` to loop through key-value pairs one by one.

# %%
# Your solution

# %% [markdown]
# After the quiz, the scores of the 4 accepted teams are stored in a dictionary:

# %%
scores = {
    "Quiztopher Nolan": 42,
    "Beer Pressure": 46,
    "Les Quizerables": 41,
    "The Quizard of Oz": 37
}

# %% [markdown]
# **(B)** **(1 P)** Write a program that:
# - Uses a `for` loop to go through the `scores` dictionary and finds the team with the highest score (the winner).
# - Prints their name and points, for example:
#
# Winner: team_name_1 (x points)

# %%
# Your solution
