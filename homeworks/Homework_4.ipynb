# %% [markdown]
# # Homework 4

# %% [markdown]
# ## Name:

# %% [markdown]
# # Problem 1:
#
# You are helping the designer of a sundial who wants to create one in a park. Since the ground is uneven, the designer uses a virtual plane perpendicular to the sundial’s stick as a reference for computing the shadow. You need to write a function that takes the exact coordinates of the stick and creates a plane perpendicular to it.
#
# **(A) Cross Product Function** **(1 P)**
#
#
# To calculate the plane, you first need a function that calculates the cross product of two vectors. Write a function that takes two lists (representing 3D vectors) as arguments and returns their cross product as a list. The cross product should be perpendicular to both input vectors.
#
# Test your function with the two vectors ````[0,0,1]```` and ````[0,1,0]````. If your function works correctly, the output should be ````[-1,0,0]````.

# %%
# Your solution

# %% [markdown]
# **(B) Plane Generation Function** **(1 P)**
#
# Using your cross product function, write a function that takes the vector of the sundial’s stick as input and returns two unit vectors, ````e1```` and ````e2````, that span the 2D plane perpendicular to the stick vector.
#
# Consider the following steps in your function:
#
# 1. Define a reference vector ````any_vec = [0,0,1]````. This vector must not be parallel to the input vector. To check this, calculate the scalar product between ````any_vec```` and the input vector. If the dot product is greater than 0.99 (for simplicity, all vectors are assumed to be normalized), the vectors are too closely aligned, and you should choose ````any_vec = [0,1,0]```` instead.
#
# 2. Calculate a vector perpendicular to both the reference vector ````any_vec```` and the input vector using your cross product function. This vector is ````e1````.
#
# 3. Calculate ````e2```` as a vector perpendicular to both ````e1```` and the input vector  using your cross product function.
#
# 4. Return ````e1```` and ````e2````.
#
# Test your function with the following stick vectors:
#
# ````[0, 0.1, 0.9]````
#
# ````[0, 0, 1]````
#
# ````[0.2, 0, 0.8]````

# %%
# Your solution

# %% [markdown]
# ## Problem 2:

# %% [markdown]
# You're helping a café automate their billing system.
#
# **(A) Apply a tax** **(1 P)**
#
# Write a function ````apply_tax```` that takes the price and the tax rate percentage and returns the price after the tax has been applied.
#
# Print the output of the function for ````price = 100```` and ````tax_rate = 7````.

# %%
# Your solution

# %% [markdown]
# **(B) Apply a discount** **(1 P)**
#
# Write a function ````apply_discount```` that takes the price and discount rate percentage and returns the price after the discount has been applied.
#
# Print the output of the function for ````price = 100```` and ````tax_rate = 10````.

# %%
# Your solution

# %% [markdown]
# **(C) Flexible price calculator** **(1 P)**
#
# Write a function called ````calculate_bill```` that can handle any number of ordered items and optional discounts or taxes, and returns the total price after tax and discount rounded to 2 decimals. Use the functions ````apply_tax```` and ````apply_discount```` that you wrote above.
#
# Print the following:
#
# ````calculate_bill(12.5, 8.0, 15.5, discount=5, tax=15)````
#
# ````calculate_bill(29.0, 33.0, discount=10)````
#
# **Remember** For a function to take any number of arguments, use ````*args````. For optional keyword arguments like discount and tax, use ````**kwargs````.

# %%
# Your solution
