# %% [markdown]
# # Homework 6

# %% [markdown]
# # Name:

# %% [markdown]
# You are modelling a simple weather monitoring system.
#
# **(A)** (2P)
#
# The ```Location``` class has two instance attributes **city** and **country**. Create two different **Location** objects for Berlin, Germany and Los Angeles, USA named loc1 and loc2 respectively.

# %%
class Location:
    def __init__(self, city, country):
        self.city = city
        self.country = country

# %%
## SOLUTION

# %% [markdown]
# Write a ```WeatherStation``` class which has **station_id**, **temperature** and **location** as instance attributes. **location** should be a ```Location``` instance. Use a class attribute to define temperature unit as "C" for Celsius.
#
# Create an instance of ```WeatherStation``` called 'la' which is located in Los Angeles with **station_id="LA"** and **temperature=15**.

# %%
## SOLUTION

# %% [markdown]
# **(B)** (1P)
#
# We tried to implement a property with a setter on the ```WeatherStation``` class. A temperature can only take the values between and including -90 and 60. But our code has a lot of errors! Copy the incorrect code below to a new cell and correct the mistakes in the property and setter method.

# %%
class WeatherStation:
 
    def __init__(self, station_id, temperature, location):
        # YOUR CODE FROM ABOVE

    @property
    def temperature(self)
        return temperature

    @temperature.setter
    def temp(value):
        if value > -90 and value < 60
            _temperature = value
        else:
            print("wrong temperature!")

# %%
## SOLUTION

# %% [markdown]
# **(C)** (2P)
#
# Now, we want to extend the ```WeatherStation``` class with two more methods: ```change_unit``` and ```is_freezing```.
#
# Write a ```change_unit``` method that changes the temperature unit for all ```WeatherStation``` objects. Calling this method should set the class attribute ```unit``` to ```new_unit``` which can only be "C" or "F".

# %%
class WeatherStation:
    
    unit = "C"  

    def __init__(self, station_id, temperature, location):
    # YOUR CODE FROM ABOVE 

    @property
    # ...    

    @temperature.setter
    # ...

    @classmethod
    def change_unit

    @staticmethod
    def is_freezing(temp):
        if WeatherStation.unit == "C":
            return temp <= 0
        else:
            return temp <= 32

# %%
## SOLUTION

# %% [markdown]
# The ```is_freezing``` method returns **True** if temperature is below 0° C or 32° F.
#
# We have a ```WeatherStation``` in Los Angeles, that you created above. Temperatures are stored in "F" in the United States. Change the unit to "F" and check if it's freezing in LA.

# %%
## SOLUTION
